# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('messi5.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# cv2.imshow('image', img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# cv2.imwrite('dummy.jpg', img)

# %%
z= img[280: , 320:400]
z.shape
# Out:
# (62, 80, 3)

# %%
img[200:262, 100:180] = img[280: , 320:400]
plt.imshow(img)

# %%
r ,g ,b = cv2.split(img)
plt.imshow(r)

# %%
res = cv2.merge((r,g,b))
plt.imshow(res)

# %%
c= img[-1]
d = np.count_nonzero(c)
print(d)
# Out:
# 1644

# %%
d = len(c)
print(d)
# Out:
# 548

# %%
d = np.sum(c)
print(d)
# Out:
# 162987

# %%
img.shape
# Out:
# (342, 548, 3)

# %%
print(img)
# Out:
# [[[ 44  43  39]
#   [ 47  46  42]
#   [ 52  47  44]
#   ...
#   [ 55  55  57]
#   [ 53  53  55]
#   [ 50  50  52]]
#
#  [[ 44  40  37]
#   [ 49  45  42]
#   [ 54  49  46]
#   ...
#   [ 60  60  62]
#   [ 58  58  60]
#   [ 55  55  57]]
#
#  [[ 50  45  41]
#   [ 55  50  46]
#   [ 60  55  51]
#   ...
#   [ 65  63  64]
#   [ 64  62  63]
#   [ 61  59  60]]
#
#  ...
#
#  [[ 99 143  56]
#   [ 89 133  48]
#   [ 86 129  49]
#   ...
#   [ 92 134  60]
#   [ 94 134  63]
#   [103 145  73]]
#
#  [[ 96 138  54]
#   [ 99 141  59]
#   [ 87 130  50]
#   ...
#   [ 91 132  56]
#   [104 142  69]
#   [ 97 137  64]]
#
#  [[ 87 129  45]
#   [ 98 140  58]
#   [108 151  71]
#   ...
#   [ 86 124  49]
#   [ 87 125  52]
#   [ 86 124  51]]]

# %%
def display(winname , image):
    z= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cv2.imshow(winname, z)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
display('image', img)

# %%
def dis(winname , image):
#     z= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
dis('image', img)

# %%
cv2.line(img, (100,250) , (500,250), (255,255,255),10)
plt.imshow(img)

# %%
cv2.rectangle(img, (200,50) , (280,140), (255,255,255),10)
plt.imshow(img)

# %%
drawing = np.zeros([300,300,3], dtype ='uint8')
plt.imshow(drawing)

# %%
cv2.line(drawing,(300,0), (0,300) , (255,255,255),10)
plt.imshow(drawing)

# %%
cv2.rectangle(drawing, (200,50) , (280,140), (255,255,255),-1)
plt.imshow(drawing)

# %%
drawing.shape
# Out:
# (300, 300, 3)

# %%
row, column, _ = drawing.shape

# %%
d= row/2
print(d)
# Out:
# 150.0

# %%
e= column/2
print(e)
# Out:
# 150.0

# %%
cv2.circle(drawing, (20,280), 10, (123,225,157), 5)
plt.imshow(drawing)

# %%
color = np.random.randint(0,256, size=3).tolist()
print(color)
# Out:
# [24, 118, 90]

# %%
img = np.zeros([512,512,3], dtype= 'uint8')
for i in range(0,200):
    rad = np.random.randint(5,100)
    col = np.random.randint(100, 255,size= 3).tolist()
    pt = np.random.randint(0,512,size=2)
    
    cv2.circle(img,pt, rad, col, -1)
    
plt.imshow(img)

# %%
import time
cap = cv2.VideoCapture(r'vtest.avi');
fps = 0
while True:
    start_time = time.time()
    ret, frame = cap.read()
    if ret == False:
        break
    cv2.putText(frame, f'fps: {fps}', (30,80), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (255,255,255), 5)    
        
    cv2.imshow('frame', frame)
    if cv2.waitKey(41) & 0xFF == ord('q'):
        break
        
    time_taken = time.time() - start_time
    fps = 1/time_taken
#     print(fps)
cap.release()
cv2.destroyAllWindows()

# %%
img1 = cv2.imread("tree_image.jpeg")
plt.imshow(img1)

# %%
tx=50
ty=40
M= np.float32([[1,0,tx],
         [0,1,ty]])

shifted_img = cv2.warpAffine(img1, M , (img1.shape[1], img1.shape[0]))
plt.imshow(shifted_img)

# %%
tx= -50
ty= -40
M= np.float32([[1,0,tx],
         [0,1,ty]])

shifted_img = cv2.warpAffine(img1, M , (img1.shape[1], img1.shape[0]))
plt.imshow(shifted_img)

# %%
center = (img1.shape[1]//2, img1.shape[0]//2)
print(center)
# Out:
# (131, 96)

# %%
N = cv2.getRotationMatrix2D(center, 180,2)
N
# Out:
# array([[-2.0000000e+00,  2.4492936e-16,  3.9300000e+02],
#        [-2.4492936e-16, -2.0000000e+00,  2.8800000e+02]])

# %%
rotate_img = cv2.warpAffine(img1, N , (img1.shape[1], img1.shape[0]))
plt.imshow(rotate_img)

# %%
resize_img = cv2.resize(img1, (100,60), interpolation =cv2.INTER_AREA)
plt.imshow(resize_img)

# %%
resize_img = cv2.resize(img1, (60,100), interpolation =cv2.INTER_AREA)
plt.imshow(resize_img)

# %%
flip_img = cv2.flip(img1, -1)
plt.imshow(flip_img)

# %%
flip_img = cv2.flip(img1, 1)
plt.imshow(flip_img)

# %%
flip_img = cv2.flip(img1, 0)
plt.imshow(flip_img)

# %%
value = np.ones_like(img1, dtype= 'uint8')*80
plt.imshow(value)

# %%
add_img_data= cv2.add(img1,value)
plt.imshow(add_img_data)

# %%
subtract_img_data= cv2.subtract(img1,value)
plt.imshow(subtract_img_data)

# %%
subtract_img_data = cv2.addWeighted(img1,0.8,value,0.2,50)
plt.imshow(subtract_img_data)

# %%
subtract_img_data = cv2.addWeighted(img1,0.8,value,0.2,-50)
plt.imshow(subtract_img_data)

# %%
import cv2
import numpy as np

def nothing(x):
    print(x)

img = np.zeros((512,512,3),dtype = 'uint8')
cv2.namedWindow('image')

cv2.createTrackbar('B','image', 0, 255, nothing)
cv2.createTrackbar('G','image', 0, 255, nothing)
cv2.createTrackbar('R','image', 0, 255, nothing)

switch = '0 : OFF\n 1 : ON'
cv2.createTrackbar(switch,'image', 0, 1, nothing)

while(1):
    cv2.imshow("image",img)
    k  =  cv2.waitKey(1) 
    if k != -1:
        break
    
    b= cv2.getTrackbarPos('B','image')
    g= cv2.getTrackbarPos('G','image')
    r= cv2.getTrackbarPos('R','image')
    s= cv2.getTrackbarPos(switch, 'image')
    
    
    if s== 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]
        
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img1= np.zeros([500,500, 3] ,np.uint8)
img1 = cv2.rectangle(img1, (130,150), (350,380), (255,255,255), -1)
img2= np.zeros([500,500, 3] ,np.uint8)
img2 = cv2.circle(img2, (150,250), 100, (255,255,255), -1)

plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
bitAnd = cv2.bitwise_and(img2,img1)
plt.imshow(bitAnd)

# %%
bitor = cv2.bitwise_or(img2,img1)
plt.imshow(bitor)

# %%
bitxor = cv2.bitwise_xor(img2,img1)
plt.imshow(bitxor)

# %%
bitnot = cv2.bitwise_not(img1)
plt.imshow(bitnot)

# %%
bitnot = cv2.bitwise_not(img2)
plt.imshow(bitnot)

# %%
res= cv2.imread('tree_image.jpeg')
plt.imshow(res)

# %%
mask = np.zeros(res.shape[:2], dtype= 'uint8')
plt.imshow(mask)

# %%
mask = cv2.rectangle(mask, (50,25), (200,125), (255,255,255), -1)
plt.imshow(mask)

# %%
masking_img = cv2.bitwise_and(res,res,mask=mask)
plt.imshow(masking_img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('noise.jpg')
img =cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


kernal =np.ones((5 ,5), np.float32)/25

dst = cv2.filter2D(img, -1, kernal)
blur = cv2.blur(img, (7,7))
gblur = cv2.GaussianBlur(img, (7,7), 0)
median = cv2.medianBlur(img,7)
bilateralFilter = cv2.bilateralFilter(img, 9, 75, 75)

titles = ['img', 'dst' ,'blur', "gblur", 'median', 'bilateralFilter']
images = [img,dst ,blur ,gblur,median,bilateralFilter]

for i in range(6):
    plt.subplot(2,3, i+1), plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ![image](car1.jpg)

# %%
white_img = np.zeros([300,300,3], dtype = 'uint8')
white_img.fill(255)
plt.imshow(white_img)

# %%
white_img = [255,0,0]
plt.imshow(white_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-2562ebe41401> in <module>
#       1 white_img = [255,0,0]
# ----> 2 plt.imshow(white_img)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
imga = np.zeros([100,100,3])
h = len(imga)
w = len(imga[0])

for y in range(h):
    for x in range(w):
        imga[y,x] = [255,255,255]
plt.imshow(imga)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imga[:] = [0,0,255]
plt.imshow(imga)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
image = cv2.imread("white.jpg")
plt.imshow(image)

# %%
image[np.where((image>[127, 215, 115]).all(axis=2))] = [0,0,255]
plt.imshow(image)

# %%
image = cv2.imread("white_color.jpg")
plt.imshow(image)

# %%
image[np.where((image==[255, 255, 255]).all(axis=2))] = [0,0,255]
plt.imshow(image)
# Out:
#   File "<ipython-input-108-22a0061aa578>", line 1
#     image[np.where((image=[255, 255, 255]).all(axis=2))] = [0,0,255]
#                          ^
# SyntaxError: invalid syntax
